# %%
#Import Libraries
import numpy as np
import pandas as pd
import statsmodels.api as sm
import matplotlib.pyplot as plt
import seaborn
seaborn.set()

# %%
#Check Directory
os.getcwd()
# Out:
# 'C:\\Users\\zara\\Documents\\Data Science Portfolio_Zara Clacken\\MBA 701 Econ Assignments Redone in R & Python'

# %%
#Import Data Frame 
crimestats = pd.read_excel("State Crime.xlsx")

# %% [markdown]
# # Data Mining and Cleaning

# %%
#Check the head of the data frame 
crimestats.head()
# Out:
#   Table 5, Crime in the United States by State, 2019, Rate per 100,000 inhabitants  \
# 0                                                NaN
# 1  https://ucr.fbi.gov/crime-in-the-u.s/2019/crim...
# 2                                              State
# 3                                            ALABAMA
# 4                                            ARIZONA
#
#       Unnamed: 1          Unnamed: 2                            Unnamed: 3  \
# 0  Violent crime  Aggravated assault  Murder and nonnegligent manslaughter
# 1            NaN                 NaN                                   NaN
# 2        Violent             Assault                                Murder
# 3          510.8                 381                                   7.3
# 4          455.3               311.9                                     5
#
#   Unnamed: 4      Unnamed: 5 Unnamed: 6     Unnamed: 7           Unnamed: 8  \
# 0    Robbery  Property crime   Burglary  Larceny-theft  Motor vehicle theft
# ...

# %%
#Count number of Rows 
len(crimestats)
# Out:
# 51

# %%
#Drop Row 0 and 1 since they are not important
crimestats = crimestats[2:51] #note, this calls rows by index number

# %%
#Check the head once again 
crimestats.head()
# Out:
#   Table 5, Crime in the United States by State, 2019, Rate per 100,000 inhabitants  \
# 2                                              State
# 3                                            ALABAMA
# 4                                            ARIZONA
# 5                                           ARKANSAS
# 6                                         CALIFORNIA
#
#   Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5 Unnamed: 6  \
# 2    Violent    Assault     Murder    Robbery  PropCrime   Burglary
# 3      510.8        381        7.3       80.4     2674.4      531.9
# 4      455.3      311.9          5       88.1     2440.5      394.3
# 5      584.6      447.8          8       51.6       2858      599.6
# 6      441.2      267.1        4.3      132.4     2331.2      386.1
#
#   Unnamed: 7 Unnamed: 8  Unnamed: 9  ... Unnamed: 16 Unnamed: 17 Unnamed: 18  \
# 2    Larceny   CarTheft         NaN  ...        Temp         Sun        Rain
# ...

# %%
#Check the tail as well 
crimestats.tail()
# Out:
#    Table 5, Crime in the United States by State, 2019, Rate per 100,000 inhabitants  \
# 46                                           VIRGINIA
# 47                                         WASHINGTON
# 48                                      WEST VIRGINIA
# 49                                          WISCONSIN
# 50                                            WYOMING
#
#    Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5 Unnamed: 6  \
# 46        208      128.7          5       41.3     1642.7      162.8
# 47      293.9      179.9        2.6       67.6     2681.9      453.6
# 48      316.6      249.1        4.4       21.1     1583.4      328.7
# 49      293.2        200          3       51.4     1471.4      217.6
# 50      217.4      147.6        2.2       11.6     1571.1      241.2
#
#    Unnamed: 7 Unnamed: 8  Unnamed: 9  ... Unnamed: 16 Unnamed: 17 Unnamed: 18  \
# 46     1359.5      120.3         NaN  ...        55.1         100        44.3
# ...

# %%
#Count rows after subsetting
len(crimestats)
# Out:
# 49

# %%
#Call Row 2 and name it as object row 2 
row2 = crimestats.loc[[2]] #call row by the label number

# %%
#Turn Row 2 into an Array and make it an object
newcolumnnames = np.array(row2)

# %%
#check array
print(newcolumnnames)
# Out:
# [['State' 'Violent' 'Assault' 'Murder' 'Robbery' 'PropCrime' 'Burglary'
#   'Larceny' 'CarTheft' nan 'Population' 'PerCapIncome' '%Metro'
#   '%Bachelors+' '%Unemploy' '%Poverty' 'Temp' 'Sun' 'Rain' '%SameHouse'
#   'MedianAge' 'MedAgeMale' 'MedAgeFemale' '%young' '%youngmale'
#   '%youngfemale']]

# %%
print(newcolumnnames.tolist())
# Out:
# [['State', 'Violent', 'Assault', 'Murder', 'Robbery', 'PropCrime', 'Burglary', 'Larceny', 'CarTheft', nan, 'Population', 'PerCapIncome', '%Metro', '%Bachelors+', '%Unemploy', '%Poverty', 'Temp', 'Sun', 'Rain', '%SameHouse', 'MedianAge', 'MedAgeMale', 'MedAgeFemale', '%young', '%youngmale', '%youngfemale']]

# %%
#Convert Original Columns Names into an Array 
np.array(crimestats.columns)
# Out:
# array(['Table 5, Crime in the United States by State, 2019, Rate per 100,000 inhabitants',
#        'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4',
#        'Unnamed: 5', 'Unnamed: 6', 'Unnamed: 7', 'Unnamed: 8',
#        'Unnamed: 9',
#        'Non-crime variables; units are as specified in row 2 descriptors',
#        'Unnamed: 11', 'Unnamed: 12', 'Unnamed: 13', 'Unnamed: 14',
#        'Unnamed: 15', 'Unnamed: 16', 'Unnamed: 17', 'Unnamed: 18',
#        'Unnamed: 19', 'Unnamed: 20', 'Unnamed: 21', 'Unnamed: 22',
#        'Unnamed: 23', 'Unnamed: 24', 'Unnamed: 25'], dtype=object)

# %% [markdown]
# ---

# %%
#Check indexing
crimestats.iloc[0,0]
# Out:
# 'State'

# %%
#Check Indexing 
crimestats.columns[0]
# Out:
# 'Table 5, Crime in the United States by State, 2019, Rate per 100,000 inhabitants'

# %%
#Create a function for a dictionary to input into column rename function 
def namefunc():
    n = range(26)
    for i in n:
        newname = np.array(crimestats.iloc[0,i]).tolist()
        oldname = np.array(crimestats.columns[i]).tolist()
        columndict = {print("\"%s\""%oldname,":","\"%s\""%newname,",",end = " ")}  
namefunc()
# Out:
# "Table 5, Crime in the United States by State, 2019, Rate per 100,000 inhabitants" : "State" , "Unnamed: 1" : "Violent" , "Unnamed: 2" : "Assault" , "Unnamed: 3" : "Murder" , "Unnamed: 4" : "Robbery" , "Unnamed: 5" : "PropCrime" , "Unnamed: 6" : "Burglary" , "Unnamed: 7" : "Larceny" , "Unnamed: 8" : "CarTheft" , "Unnamed: 9" : "nan" , "Non-crime variables; units are as specified in row 2 descriptors" : "Population" , "Unnamed: 11" : "PerCapIncome" , "Unnamed: 12" : "%Metro" , "Unnamed: 13" : "%Bachelors+" , "Unnamed: 14" : "%Unemploy" , "Unnamed: 15" : "%Poverty" , "Unnamed: 16" : "Temp" , "Unnamed: 17" : "Sun" , "Unnamed: 18" : "Rain" , "Unnamed: 19" : "%SameHouse" , "Unnamed: 20" : "MedianAge" , "Unnamed: 21" : "MedAgeMale" , "Unnamed: 22" : "MedAgeFemale" , "Unnamed: 23" : "%young" , "Unnamed: 24" : "%youngmale" , "Unnamed: 25" : "%youngfemale" ,

# %%
columndict
# Out:
# {'Table 5, Crime in the United States by State, 2019, Rate per 100,000 inhabitants': 'State',
#  'Unnamed: 1': 'Violent',
#  'Unnamed: 2': 'Assault',
#  'Unnamed: 3': 'Murder',
#  'Unnamed: 4': 'Robbery',
#  'Unnamed: 5': 'PropCrime',
#  'Unnamed: 6': 'Burglary',
#  'Unnamed: 7': 'Larceny',
#  'Unnamed: 8': 'CarTheft',
#  'Unnamed: 9': 'nan',
#  'Non-crime variables; units are as specified in row 2 descriptors': 'Population',
#  'Unnamed: 11': 'PerCapIncome',
#  'Unnamed: 12': '%Metro',
#  'Unnamed: 13': '%Bachelors+',
#  'Unnamed: 14': '%Unemploy',
#  'Unnamed: 15': '%Poverty',
#  'Unnamed: 16': 'Temp',
#  'Unnamed: 17': 'Sun',
#  'Unnamed: 18': 'Rain',
#  'Unnamed: 19': '%SameHouse',
#  'Unnamed: 20': 'MedianAge',
#  'Unnamed: 21': 'MedAgeMale',
#  'Unnamed: 22': 'MedAgeFemale',
#  'Unnamed: 23': '%young',
#  'Unnamed: 24': '%youngmale',
#  'Unnamed: 25': '%youngfemale'}

# %%
#rename data frame's columns using dictionary 
crimestats = crimestats.rename(columns=columndict)

# %%
#Check if data frames column names have changed
crimestats.head()
# Out:
#         State  Violent  Assault  Murder  Robbery  PropCrime  Burglary  \
# 2       State  Violent  Assault  Murder  Robbery  PropCrime  Burglary
# 3     ALABAMA    510.8      381     7.3     80.4     2674.4     531.9
# 4     ARIZONA    455.3    311.9       5     88.1     2440.5     394.3
# 5    ARKANSAS    584.6    447.8       8     51.6       2858     599.6
# 6  CALIFORNIA    441.2    267.1     4.3    132.4     2331.2     386.1
#
#    Larceny  CarTheft  nan  ...  Temp  Sun  Rain  %SameHouse  MedianAge  \
# 2  Larceny  CarTheft  NaN  ...  Temp  Sun  Rain  %SameHouse  MedianAge
# 3   1886.1     256.5  NaN  ...  62.8   99  58.3     86.2748         39
# 4   1796.9     249.4  NaN  ...  60.3  193  13.6     82.5992       37.7
# 5   2012.6     245.9  NaN  ...  60.4  123  50.6     84.5835       38.1
# 6   1586.3     358.8  NaN  ...  59.4  146  22.2     87.1416       36.5
#
#    MedAgeMale  MedAgeFemale    %young  %youngmale  %youngfemale
# ...

# %%
#Drop Row Label 2 
crimestats = crimestats.drop(2, 0) #2 is the label and 0 indicates a row is being dropped

# %%
#Check head again
crimestats.head()
# Out:
#         State Violent Assault Murder Robbery PropCrime Burglary Larceny  \
# 3     ALABAMA   510.8     381    7.3    80.4    2674.4    531.9  1886.1
# 4     ARIZONA   455.3   311.9      5    88.1    2440.5    394.3  1796.9
# 5    ARKANSAS   584.6   447.8      8    51.6      2858    599.6  2012.6
# 6  CALIFORNIA   441.2   267.1    4.3   132.4    2331.2    386.1  1586.3
# 7    COLORADO     381   246.3    3.8    63.6    2590.7    348.4  1858.3
#
#   CarTheft  nan  ...  Temp  Sun  Rain %SameHouse MedianAge MedAgeMale  \
# 3    256.5  NaN  ...  62.8   99  58.3    86.2748        39       36.9
# 4    249.4  NaN  ...  60.3  193  13.6    82.5992      37.7       35.5
# 5    245.9  NaN  ...  60.4  123  50.6    84.5835      38.1       36.3
# 6    358.8  NaN  ...  59.4  146  22.2    87.1416      36.5       34.6
# 7      384  NaN  ...  45.1  136  15.9    82.0307      36.7       35.5
#
#   MedAgeFemale    %young %youngmale %youngfemale
# 3         39.8  0.162112   0.166881     0.157552
# ...

# %%
#Check Tail Again 
crimestats.tail()
# Out:
#             State Violent Assault Murder Robbery PropCrime Burglary Larceny  \
# 46       VIRGINIA     208   128.7      5    41.3    1642.7    162.8  1359.5
# 47     WASHINGTON   293.9   179.9    2.6    67.6    2681.9    453.6  1907.9
# 48  WEST VIRGINIA   316.6   249.1    4.4    21.1    1583.4    328.7  1119.7
# 49      WISCONSIN   293.2     200      3    51.4    1471.4    217.6    1127
# 50        WYOMING   217.4   147.6    2.2    11.6    1571.1    241.2  1206.7
#
#    CarTheft  nan  ...  Temp  Sun  Rain %SameHouse MedianAge MedAgeMale  \
# 46    120.3  NaN  ...  55.1  100  44.3    84.7435      38.2       36.4
# 47    320.5  NaN  ...  48.3   58  38.4    82.2926      37.7       36.5
# 48      135  NaN  ...  51.8   60  45.2    88.3447      42.5       40.5
# 49    126.8  NaN  ...  43.1   89  32.6    86.0183      39.5       37.8
# 50    123.2  NaN  ...    42  114  12.9    83.1709      37.7       36.1
#
#    MedAgeFemale    %young %youngmale %youngfemale
# ...

# %%
#Drop the column with NaN values which is column index number 9 
crimestats = crimestats.drop("nan", 1)

# %%
crimestats.head()
# Out:
#         State Violent Assault Murder Robbery PropCrime Burglary Larceny  \
# 3     ALABAMA   510.8     381    7.3    80.4    2674.4    531.9  1886.1
# 4     ARIZONA   455.3   311.9      5    88.1    2440.5    394.3  1796.9
# 5    ARKANSAS   584.6   447.8      8    51.6      2858    599.6  2012.6
# 6  CALIFORNIA   441.2   267.1    4.3   132.4    2331.2    386.1  1586.3
# 7    COLORADO     381   246.3    3.8    63.6    2590.7    348.4  1858.3
#
#   CarTheft Population  ...  Temp  Sun  Rain %SameHouse MedianAge MedAgeMale  \
# 3    256.5    4903185  ...  62.8   99  58.3    86.2748        39       36.9
# 4    249.4    7278717  ...  60.3  193  13.6    82.5992      37.7       35.5
# 5    245.9    3017804  ...  60.4  123  50.6    84.5835      38.1       36.3
# 6    358.8   39512223  ...  59.4  146  22.2    87.1416      36.5       34.6
# 7      384    5758736  ...  45.1  136  15.9    82.0307      36.7       35.5
#
#   MedAgeFemale    %young %youngmale %youngfemale
# ...

# %%
#View summary of data frame information after cleaning 
crimestats.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 48 entries, 3 to 50
# Data columns (total 25 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   State         48 non-null     object
#  1   Violent       48 non-null     object
#  2   Assault       48 non-null     object
#  3   Murder        48 non-null     object
#  4   Robbery       48 non-null     object
#  5   PropCrime     48 non-null     object
#  6   Burglary      48 non-null     object
#  7   Larceny       48 non-null     object
#  8   CarTheft      48 non-null     object
#  9   Population    48 non-null     object
#  10  PerCapIncome  48 non-null     object
#  11  %Metro        48 non-null     object
#  12  %Bachelors+   48 non-null     object
#  13  %Unemploy     48 non-null     object
#  14  %Poverty      48 non-null     object
#  15  Temp          48 non-null     object
#  16  Sun           48 non-null     object
#  17  Rain          48 non-null     object
# ...

# %% [markdown]
# # Run Multiple Linear Regressions

# %%
#Model A: Robbery = f(%Metro, %Poverty, Rain)
#Model B: Robbery = f(Population, %SameHouse, MedianAge)
#Model C: Robbery = f(Population, %SameHouse, MedAgeMale)
#Model D: Robbery = f(Population, %SameHouse, MedAgeFemale)
#Model E: Robbery = f(CarTheft, %Unemploy, %Bachelors+, Temp)
#Model F: Robbery = f(CarTheft, %Unemploy, %Bachelors+, Sun)
#Model G: Robbery = f(CarTheft, %Unemploy, %Bachelors+, Rain)

# %%
#Define Dependent and Idependent Variables
y = crimestats["Robbery"]
x1A = crimestats[["%Metro", "%Poverty", "Rain"]]
x1B = crimestats[["Population", "%SameHouse", "MedianAge"]]
x1C = crimestats[["Population", "%SameHouse", "MedAgeMale"]]
x1D = crimestats[["Population", "%SameHouse", "MedAgeFemale"]]
x1E = crimestats[["CarTheft", "%Unemploy", "%Bachelors+", "Temp"]]
x1F = crimestats[["CarTheft", "%Unemploy", "%Bachelors+", "Sun"]]
x1G = crimestats[["CarTheft", "%Unemploy", "%Bachelors+", "Rain"]]

# %%
#Generate the constants for the y-intercept 
xA = sm.add_constant(x1A)
xB = sm.add_constant(x1B)
xC = sm.add_constant(x1C)
xD = sm.add_constant(x1D)
xE = sm.add_constant(x1E)
xF = sm.add_constant(x1F)
xG = sm.add_constant(x1G)

# %%
#Model A Regression 
#Since the variables in the data frame are object types instead of numeric types you can set the parameters of the regression to float
results = sm.OLS(y.astype(float),xA.astype(float)).fit()
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                Robbery   R-squared:                       0.537
# Model:                            OLS   Adj. R-squared:                  0.505
# Method:                 Least Squares   F-statistic:                     16.99
# Date:                Wed, 22 Dec 2021   Prob (F-statistic):           1.79e-07
# Time:                        00:13:35   Log-Likelihood:                -215.57
# No. Observations:                  48   AIC:                             439.1
# Df Residuals:                      44   BIC:                             446.6
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        -84.9664     22.641     -3.753      0.001    -130.597     -39.336
# ...

# %%
#Model B Regression
results = sm.OLS(y.astype(float),xB.astype(float)).fit()
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                Robbery   R-squared:                       0.365
# Model:                            OLS   Adj. R-squared:                  0.322
# Method:                 Least Squares   F-statistic:                     8.426
# Date:                Wed, 22 Dec 2021   Prob (F-statistic):           0.000155
# Time:                        00:34:15   Log-Likelihood:                -223.14
# No. Observations:                  48   AIC:                             454.3
# Df Residuals:                      44   BIC:                             461.8
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       -125.1410    174.711     -0.716      0.478    -477.248     226.966
# ...

# %%
#Model C Regression
results = sm.OLS(y.astype(float),xC.astype(float)).fit()
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                Robbery   R-squared:                       0.383
# Model:                            OLS   Adj. R-squared:                  0.341
# Method:                 Least Squares   F-statistic:                     9.091
# Date:                Wed, 22 Dec 2021   Prob (F-statistic):           8.48e-05
# Time:                        00:34:27   Log-Likelihood:                -222.46
# No. Observations:                  48   AIC:                             452.9
# Df Residuals:                      44   BIC:                             460.4
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       -106.5479    169.824     -0.627      0.534    -448.806     235.710
# ...

# %%
#Model D Regression
results = sm.OLS(y.astype(float),xD.astype(float)).fit()
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                Robbery   R-squared:                       0.362
# Model:                            OLS   Adj. R-squared:                  0.318
# Method:                 Least Squares   F-statistic:                     8.315
# Date:                Wed, 22 Dec 2021   Prob (F-statistic):           0.000172
# Time:                        00:35:52   Log-Likelihood:                -223.26
# No. Observations:                  48   AIC:                             454.5
# Df Residuals:                      44   BIC:                             462.0
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# ...

# %%
#Model E Regression
results = sm.OLS(y.astype(float),xE.astype(float)).fit()
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                Robbery   R-squared:                       0.572
# Model:                            OLS   Adj. R-squared:                  0.533
# Method:                 Least Squares   F-statistic:                     14.39
# Date:                Wed, 22 Dec 2021   Prob (F-statistic):           1.55e-07
# Time:                        00:36:08   Log-Likelihood:                -213.65
# No. Observations:                  48   AIC:                             437.3
# Df Residuals:                      43   BIC:                             446.6
# Df Model:                           4
# Covariance Type:            nonrobust
# ...
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# const        -204.8832     41.074     -4.988      0.000    -287.716    -122.051
# ...

# %%
#Model F Regression
results = sm.OLS(y.astype(float),xF.astype(float)).fit()
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                Robbery   R-squared:                       0.444
# Model:                            OLS   Adj. R-squared:                  0.392
# Method:                 Least Squares   F-statistic:                     8.571
# Date:                Wed, 22 Dec 2021   Prob (F-statistic):           3.54e-05
# Time:                        00:36:45   Log-Likelihood:                -219.97
# No. Observations:                  48   AIC:                             449.9
# Df Residuals:                      43   BIC:                             459.3
# Df Model:                           4
# Covariance Type:            nonrobust
# ...
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# const        -128.5383     40.339     -3.186      0.003    -209.889     -47.187
# ...

# %%
#Model G Regression
results = sm.OLS(y.astype(float),xG.astype(float)).fit()
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                Robbery   R-squared:                       0.494
# Model:                            OLS   Adj. R-squared:                  0.447
# Method:                 Least Squares   F-statistic:                     10.51
# Date:                Wed, 22 Dec 2021   Prob (F-statistic):           4.99e-06
# Time:                        00:37:10   Log-Likelihood:                -217.67
# No. Observations:                  48   AIC:                             445.3
# Df Residuals:                      43   BIC:                             454.7
# Df Model:                           4
# Covariance Type:            nonrobust
# ...
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# const        -142.2632     38.255     -3.719      0.001    -219.413     -65.114
# ...
